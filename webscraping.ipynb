# %%
import pandas as pd
iris_df = pd.read_csv(r'/content/index.csv')
print("first 5 rows of the dataset: ")
print(iris_df.head())
rows, columns = iris_df.shape
print(f"Number of rows {rows} and  Number of columns{columns} ")
print("\nDataset Information: ")
print(iris_df.info())
print(iris_df.describe())
print(f"Null values {iris_df.isnull().sum()}")
print(iris_df.shape)

print("Dataset Type: Structured data")
# Out:
# first 5 rows of the dataset:
#   location_key                     place_id wikidata_id datacommons_id  \
# 0           AD  ChIJlfCemC71pRIRkn_qeNc-yQc        Q228    country/AND
# 1           AE  ChIJvRKrsd9IXj4RpwoIwFYv0zM        Q878    country/ARE
# 2           AF  ChIJbQL_-LZu0TgReNqWvg1GtfM        Q889    country/AFG
# 3       AF_BAL  ChIJWZOescNSyzgRkmVJ8fmfR3k     Q121104            NaN
# 4       AF_BAM  ChIJw-bKQwDr0jgRQiw8jHsQ-HI     Q171382            NaN
#
#   country_code          country_name subregion1_code subregion1_name  \
# 0           AD               Andorra             NaN             NaN
# 1           AE  United Arab Emirates             NaN             NaN
# 2           AF           Afghanistan             NaN             NaN
# 3           AF           Afghanistan             BAL           Balkh
# 4           AF           Afghanistan             BAM          Bamyan
#
#   subregion2_code subregion2_name locality_code locality_name  \
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = "https://www.bahria.edu.pk/page/PageTemplate4?pageContentId=4603&WebsiteID=5"
response = requests.get(url)
print("Status Code:",response.status_code)
soup = BeautifulSoup(response.content, "html.parser")
headings = []
for tag in soup.find_all(["h1","h2","h3"]):
  headings.append({
      "Heading_Type":tag.name,
      "Heading_Text": tag.get_text(strip=True)
  })
df = pd.DataFrame(headings)
print("Extracted Headings: ")
print(df)
df.to_csv("bahria_university_headings.csv", index=False)
print("successfully saved to bahria_university_headings.csv")
# Out:
# Status Code: 200
# Extracted Headings:
#   Heading_Type                            Heading_Text
# 0           h1                       Bahria University
# 1           h1  Faculty of Computer Science Department
# 2           h3
# 3           h1
# 4           h2                       Bahria University
# 5           h2                 Expansion & Procurement
# 6           h2                          BU Documentary
# 7           h2                               Locations
# successfully saved to bahria_university_headings.csv

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.daraz.pk/"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

print("Status Code:", response.status_code)

soup = BeautifulSoup(response.content, "html.parser")

headings = []

for tag in soup.find_all(["h1","h2","h3"]):
    headings.append({
        "Heading_Type": tag.name,
        "Heading_Text": tag.get_text(strip=True)
    })

print("Total Headings Found:", len(headings))

df = pd.DataFrame(headings)

print(df.head(17))

df.to_csv("new1.csv", index=False)
print(df.shape)
print("CSV Saved Successfully")
# Out:
# Status Code: 200
# Total Headings Found: 17
#    Heading_Type                                       Heading_Text
# 0            h3                                      Customer Care
# 1            h3                                              Daraz
# 2            h3                                    Payment Methods
# 3            h3                                        Verified by
# 4            h1  How Daraz Transformed Online Shopping in Pakistan
# 5            h3
# 6            h3
# 7            h3
# 8            h3
# 9            h3  What Makes Us Different from Other Online Shop...
# 10           h3
# 11           h3
# 12           h3
# 13           h3
# 14           h3                            Top Categories & Brands
# 15           h3                                Daraz International
# 16           h3                                          Follow Us
# (17, 2)
# CSV Saved Successfully
